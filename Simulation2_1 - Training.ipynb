# %% [markdown]
# # Simulation 2.1 - Training the agents
#
#
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as SGfilter
from IPython.display import clear_output, display
import datetime
import joblib
from tqdm import tqdm

import const
import utilities as ut


import gym
import ctfsql
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN
import evaluate as ev

# %% [markdown]
# ## Defining the parameters of the simulations

# %%
n_simulations = 10
n_episodes_training = 10**6
n_episodes_test = 10**2

# %%
env = gym.make('ctfsql-v0')

dqn_models = [DQN('MlpPolicy', env, verbose=1) for i in range(n_simulations)]
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## Running the simulations

# %%
train_data = np.zeros((n_simulations,3,n_episodes_training))
test_data = np.zeros((n_simulations,3,n_episodes_test))

for i in tqdm(range(n_simulations)):
    dqn_models[i].learn(total_timesteps=10**6)
    timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
    dqn_models[i].save(str(i) + 'ignore_simul2_'+timestamp)
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9406     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8848     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 503      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9335     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 689      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9497     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 9754     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1002     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 9561     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 9388     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 9337     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1667     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 9443     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 9439     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 9491     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2215     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 9707     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2459     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 9696     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.974    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 9834     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.973    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 9824     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.972    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 9848     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.972    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 9768     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2952     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.971    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 9733     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.967    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 9860     |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.964    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 10029    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.962    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 10066    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4001     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 10207    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4291     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.957    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 10225    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.954    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 10345    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 10323    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4973     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.952    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 10282    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5025     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.951    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 10265    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5109     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.95     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 10290    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.949    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 10284    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.948    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 10294    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.947    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 10299    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.943    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 10271    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.941    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 10311    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6186     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.94     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 10301    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6293     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.939    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 10290    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.938    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 10293    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.936    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 10239    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.931    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 10355    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7307     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.93     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 10328    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.929    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 10380    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7511     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.926    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 10414    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7837     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.924    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 10429    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7994     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.922    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 10421    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.918    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 10428    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8607     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.915    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 10470    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.913    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 10488    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.911    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 10430    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9399     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.909    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 10440    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.908    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 10443    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9734     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.906    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10435    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.906    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10422    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9932     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.904    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10324    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.902    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10288    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10277    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.9      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 10267    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10532    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.897    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 10269    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 10893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.894    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 10202    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.892    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 10229    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11330    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.89     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 10177    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.889    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 10170    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11650    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.888    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 10196    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 11792    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.885    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 10264    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12147    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.883    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 10233    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.879    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 10318    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 12766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.874    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 10342    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.87     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 10393    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.868    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 10422    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 13893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.866    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 10431    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14082    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.863    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 10473    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.861    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 10448    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14594    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.859    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 10478    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.858    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 10451    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 14943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.856    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 10478    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 10528    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.851    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 10512    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.85     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 10521    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.848    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 10537    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 15964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.846    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 10574    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16220    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.845    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 10548    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.842    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 10510    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.84     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 10516    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 16814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.836    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 10542    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17261    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.835    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 10538    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17328    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.834    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 10525    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.833    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 10513    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.831    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 10467    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.83     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 10426    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 17944    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.826    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 10412    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18273    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.825    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 10406    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18407    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.824    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 10403    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.823    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 10404    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18591    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.823    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 10395    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18626    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.82     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 10429    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 18978    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.815    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 10466    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.814    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 10471    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.811    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 10479    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 19885    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.808    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 10455    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 20247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.803    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 10428    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 20774    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.801    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 10397    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 20930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.799    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 10391    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.798    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 10375    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21305    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.794    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 10390    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21637    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.794    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 10384    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21727    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.792    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 10387    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 21930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.791    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 10390    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.789    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 10383    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22249    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.787    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 10387    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22402    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.785    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 10391    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22617    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.785    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 10389    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.782    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 10402    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 22923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.779    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 10384    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.779    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 10378    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.777    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 10375    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23447    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.773    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 10378    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 23878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.771    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 10387    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.77     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 10380    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.768    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 10406    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24457    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.766    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 10420    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.765    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 10419    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.764    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 10428    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 24883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.761    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 10442    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.759    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 10449    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25360    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.758    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 10456    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.755    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 10452    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.753    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 10450    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 25966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.75     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 10467    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 26364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.746    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 10487    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 26709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.745    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 10478    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 26831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.745    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 10474    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 26884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.742    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 10462    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 27135    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.741    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 10473    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 27279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.736    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 10501    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 27737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.733    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 10520    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.731    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 10518    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28275    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.731    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 10507    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28342    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.729    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 10490    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28484    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.727    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 10495    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.725    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 10483    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 28987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.723    |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 10493    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 29203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.722    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 10489    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 29264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.721    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 10480    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 29398    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.718    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 10464    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 29676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.717    |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 10459    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 29776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.714    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 10472    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30073    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.713    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 10461    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.712    |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 10461    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.71     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 10447    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30513    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.708    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 10450    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30771    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.707    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 10439    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 30833    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.705    |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 10429    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 31032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.703    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 10432    |
# |    time_elapsed     | 2        |
# |    total timesteps  | 31217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.701    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 10424    |
# |    time_elapsed     | 3        |
# |    total timesteps  | 31445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.7      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 10431    |
# |    time_elapsed     | 3        |
# |    total timesteps  | 31580    |
# ----------------------------------
# ...
# |    n_updates        | 1252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.476    |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 2134     |
# |    time_elapsed     | 25       |
# |    total timesteps  | 55210    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00231  |
# |    n_updates        | 1302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.474    |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 2090     |
# |    time_elapsed     | 26       |
# |    total timesteps  | 55360    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00254  |
# |    n_updates        | 1339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.473    |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 2058     |
# |    time_elapsed     | 26       |
# |    total timesteps  | 55479    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 1369     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.467    |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 1926     |
# |    time_elapsed     | 29       |
# |    total timesteps  | 56059    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00178  |
# |    n_updates        | 1514     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.462    |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 1802     |
# |    time_elapsed     | 31       |
# |    total timesteps  | 56641    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0022   |
# |    n_updates        | 1660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.46     |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 1771     |
# |    time_elapsed     | 32       |
# |    total timesteps  | 56797    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.958    |
# |    n_updates        | 1699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.458    |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 1726     |
# |    time_elapsed     | 33       |
# |    total timesteps  | 57042    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00177  |
# |    n_updates        | 1760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.456    |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 1691     |
# |    time_elapsed     | 33       |
# |    total timesteps  | 57226    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.324    |
# |    n_updates        | 1806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.454    |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 1658     |
# |    time_elapsed     | 34       |
# |    total timesteps  | 57424    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00166  |
# |    n_updates        | 1855     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.451    |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 1604     |
# |    time_elapsed     | 35       |
# |    total timesteps  | 57755    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.325    |
# |    n_updates        | 1938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.449    |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 1557     |
# |    time_elapsed     | 37       |
# |    total timesteps  | 58003    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00198  |
# |    n_updates        | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.446    |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 1516     |
# |    time_elapsed     | 38       |
# |    total timesteps  | 58321    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.321    |
# |    n_updates        | 2080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.444    |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 1488     |
# |    time_elapsed     | 39       |
# |    total timesteps  | 58550    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00244  |
# |    n_updates        | 2137     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.44     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 1432     |
# |    time_elapsed     | 41       |
# |    total timesteps  | 58996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.643    |
# |    n_updates        | 2248     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.435    |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 1379     |
# |    time_elapsed     | 43       |
# |    total timesteps  | 59427    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.319    |
# |    n_updates        | 2356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.434    |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 1363     |
# |    time_elapsed     | 43       |
# |    total timesteps  | 59583    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.643    |
# |    n_updates        | 2395     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.432    |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 1345     |
# |    time_elapsed     | 44       |
# |    total timesteps  | 59763    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.321    |
# |    n_updates        | 2440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.431    |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 1336     |
# |    time_elapsed     | 44       |
# |    total timesteps  | 59862    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 2465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.43     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 1319     |
# |    time_elapsed     | 45       |
# |    total timesteps  | 60033    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.546    |
# |    n_updates        | 2508     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.428    |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 1303     |
# |    time_elapsed     | 46       |
# |    total timesteps  | 60214    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.352    |
# |    n_updates        | 2553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.426    |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 1239     |
# |    time_elapsed     | 48       |
# |    total timesteps  | 60413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00233  |
# |    n_updates        | 2603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.426    |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 1238     |
# |    time_elapsed     | 48       |
# |    total timesteps  | 60422    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.003    |
# |    n_updates        | 2605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.418    |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 1169     |
# |    time_elapsed     | 52       |
# |    total timesteps  | 61284    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.348    |
# |    n_updates        | 2820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.414    |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 1142     |
# |    time_elapsed     | 53       |
# |    total timesteps  | 61666    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00241  |
# |    n_updates        | 2916     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.412    |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 1123     |
# |    time_elapsed     | 55       |
# |    total timesteps  | 61930    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00209  |
# |    n_updates        | 2982     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.409    |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 1108     |
# |    time_elapsed     | 56       |
# |    total timesteps  | 62188    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 3046     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.405    |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 1083     |
# |    time_elapsed     | 57       |
# |    total timesteps  | 62615    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00253  |
# |    n_updates        | 3153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.404    |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 1075     |
# |    time_elapsed     | 58       |
# |    total timesteps  | 62749    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00228  |
# |    n_updates        | 3187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.402    |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 1062     |
# |    time_elapsed     | 59       |
# |    total timesteps  | 62974    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0016   |
# |    n_updates        | 3243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.399    |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 1048     |
# |    time_elapsed     | 60       |
# |    total timesteps  | 63238    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 3309     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.395    |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 1025     |
# |    time_elapsed     | 62       |
# |    total timesteps  | 63650    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000863 |
# |    n_updates        | 3412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.394    |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 1016     |
# |    time_elapsed     | 62       |
# |    total timesteps  | 63824    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.346    |
# |    n_updates        | 3455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.392    |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 1004     |
# |    time_elapsed     | 63       |
# |    total timesteps  | 64012    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00142  |
# |    n_updates        | 3502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.389    |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 989      |
# |    time_elapsed     | 64       |
# |    total timesteps  | 64296    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.348    |
# |    n_updates        | 3573     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.388    |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 984      |
# |    time_elapsed     | 65       |
# |    total timesteps  | 64389    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00124  |
# |    n_updates        | 3597     |
# ----------------------------------

# %%
for i in tqdm(range(n_simulations)):
    mean_reward, _ = ev.evaluate_random(gym.make('ctfsql-v0'), num_steps=10**5)
    print('Mean reward: {0}'.format(mean_reward))
    mean_reward, _ = ev.evaluate_model(dqn_model, env, num_steps=10**5)
    print('Mean reward: {0}'.format(mean_reward))
