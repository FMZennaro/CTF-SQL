# %%
import gym

from IPython.display import display

# %%
import ctfsql
env = gym.make('ctfsql-v0')

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
env = DummyVecEnv([lambda: env])

# %%
ppomodel = PPO('MlpPolicy', env, verbose=1)
ppomodel.learn(total_timesteps=10**6)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 306  |
# |    iterations      | 1    |
# |    time_elapsed    | 6    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.022537196 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | -559        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0376     |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 3           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018477578 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | -135        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 109         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 192         |
# |    iterations           | 4           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.044809274 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | -10.5       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 100         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 191         |
# |    iterations           | 5           |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.054807235 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | -5.58       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0609     |
# |    value_loss           | 57.4        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 190        |
# |    iterations           | 6          |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.04202178 |
# |    clip_fraction        | 0.435      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.31      |
# |    explained_variance   | -2.3       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.81       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0774    |
# |    value_loss           | 21.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 189         |
# |    iterations           | 7           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.057582982 |
# |    clip_fraction        | 0.632       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -7.64       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.4         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0986     |
# |    value_loss           | 8.9         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 190         |
# |    iterations           | 8           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.046600547 |
# |    clip_fraction        | 0.857       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | -70.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.58        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.127      |
# |    value_loss           | 3.95        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 184        |
# |    iterations           | 9          |
# |    time_elapsed         | 100        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03588607 |
# |    clip_fraction        | 0.963      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.76      |
# |    explained_variance   | -17.3      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.328      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.151     |
# |    value_loss           | 1.44       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 176        |
# |    iterations           | 10         |
# |    time_elapsed         | 115        |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.20635973 |
# |    clip_fraction        | 0.975      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.622     |
# |    explained_variance   | -117       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0553     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.156     |
# |    value_loss           | 0.705      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 177        |
# |    iterations           | 11         |
# |    time_elapsed         | 126        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.24691164 |
# |    clip_fraction        | 0.0877     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0806    |
# |    explained_variance   | -910       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0273    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0739    |
# |    value_loss           | 0.133      |
# ----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 12            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | -7.629022e-05 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0194       |
# |    explained_variance   | -6.55e+07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.19e-07      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000704     |
# |    value_loss           | 0.000851      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 175           |
# |    iterations           | 13            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00058396487 |
# |    clip_fraction        | 0.00137       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0129       |
# |    explained_variance   | -1.53e+03     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.03e-07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00213      |
# |    value_loss           | 0.00178       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 176           |
# |    iterations           | 14            |
# |    time_elapsed         | 162           |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00012913998 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0101       |
# |    explained_variance   | -407          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.69e-06      |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000693     |
# |    value_loss           | 0.000593      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 177           |
# |    iterations           | 15            |
# |    time_elapsed         | 173           |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00021408033 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0079       |
# |    explained_variance   | -2.68e+04     |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0152       |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000693     |
# |    value_loss           | 0.000595      |
# -------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 177      |
# |    iterations           | 16       |
# |    time_elapsed         | 184      |
# |    total_timesteps      | 32768    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00782 |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 150      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 6.45e-07 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 178          |
# |    iterations           | 17           |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0002445476 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00606     |
# |    explained_variance   | -1.77e+03    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.79e-06     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000693    |
# |    value_loss           | 0.000596     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 178           |
# |    iterations           | 18            |
# |    time_elapsed         | 206           |
# |    total_timesteps      | 36864         |
# | train/                  |               |
# |    approx_kl            | 0.00031403592 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00453      |
# |    explained_variance   | -977          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.0152       |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000693     |
# |    value_loss           | 0.000596      |
# -------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 175      |
# |    iterations           | 19       |
# |    time_elapsed         | 221      |
# |    total_timesteps      | 38912    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00437 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 180      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 6.54e-07 |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 173          |
# |    iterations           | 20           |
# |    time_elapsed         | 236          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0003594677 |
# |    clip_fraction        | 0.000439     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00326     |
# |    explained_variance   | -5.81e+03    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.31e-06     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000692    |
# |    value_loss           | 0.000602     |
# ------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 172      |
# |    iterations           | 21       |
# |    time_elapsed         | 249      |
# |    total_timesteps      | 43008    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00313 |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 200      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 1.12e-07 |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 172      |
# |    iterations           | 22       |
# |    time_elapsed         | 261      |
# |    total_timesteps      | 45056    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00313 |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 210      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0        |
# --------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 172      |
# |    iterations           | 23       |
# |    time_elapsed         | 272      |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00313 |
# |    explained_variance   | nan      |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 220      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 0        |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 24            |
# |    time_elapsed         | 284           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00041432027 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00211      |
# |    explained_variance   | -1.04e+03     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.87e-07      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000692     |
# |    value_loss           | 0.000608      |
# -------------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 172      |
# |    iterations           | 25       |
# |    time_elapsed         | 296      |
# |    total_timesteps      | 51200    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00203 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0        |
# |    n_updates            | 240      |
# |    policy_gradient_loss | 0        |
# |    value_loss           | 1.09e-07 |
# --------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 172           |
# |    iterations           | 26            |
# |    time_elapsed         | 307           |
# |    total_timesteps      | 53248         |
# | train/                  |               |
# |    approx_kl            | 0.00046119932 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00136      |
# |    explained_variance   | -6.15e+03     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.19e-05      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.000692     |
# |    value_loss           | 0.000615      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 173           |
# |    iterations           | 27            |
# |    time_elapsed         | 319           |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00046237046 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000925     |
# |    explained_variance   | -8.62e+04     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.17e-08      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -0.000692     |
# |    value_loss           | 0.000609      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 173       |
# |    iterations           | 28        |
# |    time_elapsed         | 330       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000902 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 270       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 6.56e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 171       |
# |    iterations           | 29        |
# |    time_elapsed         | 346       |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000902 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 280       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 167       |
# |    iterations           | 30        |
# |    time_elapsed         | 366       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000902 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 290       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 168           |
# |    iterations           | 31            |
# |    time_elapsed         | 377           |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00051176734 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000598     |
# |    explained_variance   | -1.76e+04     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.6e-05       |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -0.000692     |
# |    value_loss           | 0.000619      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 168       |
# |    iterations           | 32        |
# |    time_elapsed         | 388       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000564 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 1.74e-06  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 169       |
# |    iterations           | 33        |
# |    time_elapsed         | 399       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000564 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 1.3e-12   |
# ---------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 169           |
# |    iterations           | 34            |
# |    time_elapsed         | 411           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00052394904 |
# |    clip_fraction        | 0.000439      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000372     |
# |    explained_variance   | -4.8e+04      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.08e-05      |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.000692     |
# |    value_loss           | 0.000625      |
# -------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 169       |
# |    iterations           | 35        |
# |    time_elapsed         | 422       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 4.81e-07  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 169       |
# |    iterations           | 36        |
# |    time_elapsed         | 433       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 350       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 6.82e-13  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 169       |
# |    iterations           | 37        |
# |    time_elapsed         | 445       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 360       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 6.57e-13  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 166       |
# |    iterations           | 38        |
# |    time_elapsed         | 466       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.55e-13  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 6.05e-13  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 165       |
# |    iterations           | 39        |
# |    time_elapsed         | 481       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 1.22e-12  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 163       |
# |    iterations           | 40        |
# |    time_elapsed         | 500       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 163       |
# |    iterations           | 41        |
# |    time_elapsed         | 512       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 163       |
# |    iterations           | 42        |
# |    time_elapsed         | 525       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 410       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 163       |
# |    iterations           | 43        |
# |    time_elapsed         | 539       |
# |    total_timesteps      | 88064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 420       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 163       |
# |    iterations           | 44        |
# |    time_elapsed         | 552       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 430       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 162       |
# |    iterations           | 45        |
# |    time_elapsed         | 565       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 440       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 161       |
# |    iterations           | 46        |
# |    time_elapsed         | 581       |
# |    total_timesteps      | 94208     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 450       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 47        |
# |    time_elapsed         | 597       |
# |    total_timesteps      | 96256     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 48        |
# |    time_elapsed         | 610       |
# |    total_timesteps      | 98304     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 470       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 159       |
# |    iterations           | 49        |
# |    time_elapsed         | 629       |
# |    total_timesteps      | 100352    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 159       |
# |    iterations           | 50        |
# |    time_elapsed         | 641       |
# |    total_timesteps      | 102400    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 490       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 159       |
# |    iterations           | 51        |
# |    time_elapsed         | 653       |
# |    total_timesteps      | 104448    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 500       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 52        |
# |    time_elapsed         | 665       |
# |    total_timesteps      | 106496    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 510       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 53        |
# |    time_elapsed         | 677       |
# |    total_timesteps      | 108544    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 520       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 160       |
# |    iterations           | 54        |
# |    time_elapsed         | 689       |
# |    total_timesteps      | 110592    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 530       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 55        |
# |    time_elapsed         | 709       |
# |    total_timesteps      | 112640    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 540       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 56        |
# |    time_elapsed         | 724       |
# |    total_timesteps      | 114688    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 550       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 57        |
# |    time_elapsed         | 736       |
# |    total_timesteps      | 116736    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 560       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 58        |
# |    time_elapsed         | 749       |
# |    total_timesteps      | 118784    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 570       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 157       |
# |    iterations           | 59        |
# |    time_elapsed         | 765       |
# |    total_timesteps      | 120832    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 580       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 157       |
# |    iterations           | 60        |
# |    time_elapsed         | 777       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 590       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 61        |
# |    time_elapsed         | 790       |
# |    total_timesteps      | 124928    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 600       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 62        |
# |    time_elapsed         | 802       |
# |    total_timesteps      | 126976    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 610       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 158       |
# |    iterations           | 63        |
# |    time_elapsed         | 815       |
# |    total_timesteps      | 129024    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 620       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 155       |
# |    iterations           | 64        |
# |    time_elapsed         | 843       |
# |    total_timesteps      | 131072    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 630       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 154       |
# |    iterations           | 65        |
# |    time_elapsed         | 859       |
# |    total_timesteps      | 133120    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 640       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 154       |
# |    iterations           | 66        |
# |    time_elapsed         | 872       |
# |    total_timesteps      | 135168    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 650       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ...
# |    n_updates            | 720       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 1.52e-12  |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 147       |
# |    iterations           | 74        |
# |    time_elapsed         | 1026      |
# |    total_timesteps      | 151552    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 730       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 148       |
# |    iterations           | 75        |
# |    time_elapsed         | 1036      |
# |    total_timesteps      | 153600    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 740       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 148       |
# |    iterations           | 76        |
# |    time_elapsed         | 1046      |
# |    total_timesteps      | 155648    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 750       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 149       |
# |    iterations           | 77        |
# |    time_elapsed         | 1057      |
# |    total_timesteps      | 157696    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 760       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 149       |
# |    iterations           | 78        |
# |    time_elapsed         | 1069      |
# |    total_timesteps      | 159744    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 770       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 149       |
# |    iterations           | 79        |
# |    time_elapsed         | 1080      |
# |    total_timesteps      | 161792    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 780       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 150       |
# |    iterations           | 80        |
# |    time_elapsed         | 1091      |
# |    total_timesteps      | 163840    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 790       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 150       |
# |    iterations           | 81        |
# |    time_elapsed         | 1101      |
# |    total_timesteps      | 165888    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 800       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 151       |
# |    iterations           | 82        |
# |    time_elapsed         | 1111      |
# |    total_timesteps      | 167936    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 810       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 151       |
# |    iterations           | 83        |
# |    time_elapsed         | 1121      |
# |    total_timesteps      | 169984    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 820       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 151       |
# |    iterations           | 84        |
# |    time_elapsed         | 1132      |
# |    total_timesteps      | 172032    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 830       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 151       |
# |    iterations           | 85        |
# |    time_elapsed         | 1150      |
# |    total_timesteps      | 174080    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 840       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 151       |
# |    iterations           | 86        |
# |    time_elapsed         | 1161      |
# |    total_timesteps      | 176128    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 850       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 152       |
# |    iterations           | 87        |
# |    time_elapsed         | 1172      |
# |    total_timesteps      | 178176    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 860       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 152       |
# |    iterations           | 88        |
# |    time_elapsed         | 1183      |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 870       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 152       |
# |    iterations           | 89        |
# |    time_elapsed         | 1193      |
# |    total_timesteps      | 182272    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 880       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 152       |
# |    iterations           | 90        |
# |    time_elapsed         | 1205      |
# |    total_timesteps      | 184320    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 890       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 153       |
# |    iterations           | 91        |
# |    time_elapsed         | 1217      |
# |    total_timesteps      | 186368    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 900       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 153       |
# |    iterations           | 92        |
# |    time_elapsed         | 1228      |
# |    total_timesteps      | 188416    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 910       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 153       |
# |    iterations           | 93        |
# |    time_elapsed         | 1238      |
# |    total_timesteps      | 190464    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 920       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 154       |
# |    iterations           | 94        |
# |    time_elapsed         | 1248      |
# |    total_timesteps      | 192512    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 930       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 154       |
# |    iterations           | 95        |
# |    time_elapsed         | 1257      |
# |    total_timesteps      | 194560    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | nan       |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0         |
# |    n_updates            | 940       |
# |    policy_gradient_loss | 0         |
# |    value_loss           | 0         |
# ---------------------------------------

# %%
ppomodel.save('models/PPO2-ctfsql-v0-10k')

# %%
import evaluate as ev

# %%
mean_reward, _ = ev.evaluate_random(gym.make('ctfsql-v0'), num_steps=1000)
print('Mean reward: {0}'.format(mean_reward))

# %%
mean_reward, _ = ev.evaluate_model(ppomodel, env, num_steps=1000)
print('Mean reward: {0}'.format(mean_reward))
