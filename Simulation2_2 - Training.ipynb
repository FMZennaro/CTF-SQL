# %% [markdown]
# # Simulation 2.2 - Training the agents
#
#
# ## Importing libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import savgol_filter as SGfilter
from IPython.display import clear_output, display
import datetime
import joblib
from tqdm import tqdm

import const
import utilities as ut


import gym
import ctfsql
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import DQN
import evaluate as ev

# %% [markdown]
# ## Defining the parameters of the simulations

# %%
n_simulations = 10
n_episodes_training = 10**6
n_episodes_test = 10**2

# %%
env = gym.make('ctfsql-v0')

dqn_models = [DQN('MlpPolicy', env, verbose=(i==0), exploration_final_eps = 0.1,exploration_initial_eps = 0.1) 
              for i in range(n_simulations)]
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## Running the simulations

# %%
train_data = np.zeros((n_simulations,3,n_episodes_training))
test_data = np.zeros((n_simulations,3,n_episodes_test))

for i in tqdm(range(n_simulations)):
    dqn_models[i].learn(total_timesteps=10**6)
    timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S%f")
    dqn_models[i].save(str(i) + 'ignore_simul5_'+timestamp)
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 20579    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 103      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 20751    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 270      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 20731    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 498      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 21142    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 656      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 21211    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 828      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 21659    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 21445    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 21292    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 21774    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1591     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 21765    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 21800    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 1942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 21897    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 21998    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 22056    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2605     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 22135    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 2858     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 22294    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 22334    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3532     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 22554    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 3928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 22600    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 22594    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4410     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 22524    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 4757     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 22646    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5168     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 22554    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 22577    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5446     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 22475    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5579     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 22452    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 5753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 22601    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6289     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 22566    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6392     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 22555    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6502     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 22518    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 22568    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 22482    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 6976     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 22485    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7112     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 22557    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7496     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 22519    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 7686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 22554    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 22617    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 22627    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 22570    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 8833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 22534    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 22584    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 22575    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9671     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 22540    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 9859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 22505    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10114    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 22490    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10265    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 22564    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10728    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 22580    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 10984    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 22508    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 22573    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 22555    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 22530    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 11749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 22604    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12127    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 22625    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12410    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 22565    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 22558    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 12825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 22537    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 13061    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 22575    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 13490    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 22643    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 13893    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 22611    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 14032    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 22630    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 14338    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 22598    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 14408    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 22590    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 14607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 22583    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 14715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 22599    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 15042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 22598    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 15132    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 22664    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 15698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 22682    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 22677    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 22689    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16351    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 22672    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16498    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 22657    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16600    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 22649    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16776    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 22618    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 16866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 22620    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 17117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 22603    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 17194    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 22614    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 17316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 22625    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 17709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 22610    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 17901    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 22637    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 22608    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18239    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 22589    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 22597    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18592    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 22591    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18836    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 22585    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 18921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 22576    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 22575    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19161    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 22546    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 22560    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19465    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 22541    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19606    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 22534    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 22538    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 19965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 22548    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 20335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 22530    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 20499    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 22523    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 20718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 22539    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 20958    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 22527    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 21105    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 22548    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 21486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 22589    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 21909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 22560    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 22039    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 22586    |
# |    time_elapsed     | 0        |
# |    total timesteps  | 22381    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 22572    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 22661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 22558    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 22827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 22558    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 22918    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 22534    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23187    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 22525    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23335    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 22489    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 22479    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 22484    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 22477    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 23915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 22469    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 24064    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 22492    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 24427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 22481    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 24595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 22487    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 24894    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 22484    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 24980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 22484    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 25183    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 22491    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 25393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 22497    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 25716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 22502    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 25879    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 22510    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 22489    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26202    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 22475    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 22481    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26485    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 22462    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26575    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 22459    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 22452    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 26855    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 22458    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 27042    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 22452    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 27327    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 22479    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 27698    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 22463    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 27790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 22472    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 28004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 22464    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 28106    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 22465    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 28377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 22484    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 28739    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 22498    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 29004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 22494    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 29270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 22486    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 29439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 22490    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 29715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 22499    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 29951    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 22485    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 30113    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 22484    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 30359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 22481    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 30648    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 22475    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 30797    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 22483    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 22466    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 22469    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 22469    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 22443    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 22449    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 22442    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 22443    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 31943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 22447    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 32196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 22459    |
# |    time_elapsed     | 1        |
# |    total timesteps  | 32551    |
# ----------------------------------
# ...
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17280    |
# |    fps              | 422      |
# |    time_elapsed     | 2340     |
# |    total timesteps  | 989419   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 234854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17284    |
# |    fps              | 422      |
# |    time_elapsed     | 2341     |
# |    total timesteps  | 989579   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0137   |
# |    n_updates        | 234894   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17288    |
# |    fps              | 422      |
# |    time_elapsed     | 2342     |
# |    total timesteps  | 990037   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 235009   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17292    |
# |    fps              | 422      |
# |    time_elapsed     | 2343     |
# |    total timesteps  | 990466   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 235116   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17296    |
# |    fps              | 422      |
# |    time_elapsed     | 2343     |
# |    total timesteps  | 990682   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78     |
# |    n_updates        | 235170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17300    |
# |    fps              | 422      |
# |    time_elapsed     | 2344     |
# |    total timesteps  | 991061   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 235265   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17304    |
# |    fps              | 422      |
# |    time_elapsed     | 2345     |
# |    total timesteps  | 991230   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 235307   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17308    |
# |    fps              | 422      |
# |    time_elapsed     | 2346     |
# |    total timesteps  | 991648   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 235411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17312    |
# |    fps              | 422      |
# |    time_elapsed     | 2347     |
# |    total timesteps  | 991966   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 235491   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17316    |
# |    fps              | 422      |
# |    time_elapsed     | 2348     |
# |    total timesteps  | 992374   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0352   |
# |    n_updates        | 235593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17320    |
# |    fps              | 422      |
# |    time_elapsed     | 2349     |
# |    total timesteps  | 992834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00629  |
# |    n_updates        | 235708   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17324    |
# |    fps              | 422      |
# |    time_elapsed     | 2350     |
# |    total timesteps  | 993342   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00855  |
# |    n_updates        | 235835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17328    |
# |    fps              | 422      |
# |    time_elapsed     | 2350     |
# |    total timesteps  | 993411   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0076   |
# |    n_updates        | 235852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17332    |
# |    fps              | 422      |
# |    time_elapsed     | 2351     |
# |    total timesteps  | 993600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00512  |
# |    n_updates        | 235899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17336    |
# |    fps              | 422      |
# |    time_elapsed     | 2352     |
# |    total timesteps  | 993995   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.8      |
# |    n_updates        | 235998   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17340    |
# |    fps              | 422      |
# |    time_elapsed     | 2352     |
# |    total timesteps  | 994331   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0201   |
# |    n_updates        | 236082   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17344    |
# |    fps              | 422      |
# |    time_elapsed     | 2353     |
# |    total timesteps  | 994609   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00532  |
# |    n_updates        | 236152   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17348    |
# |    fps              | 422      |
# |    time_elapsed     | 2354     |
# |    total timesteps  | 994869   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.72     |
# |    n_updates        | 236217   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17352    |
# |    fps              | 422      |
# |    time_elapsed     | 2354     |
# |    total timesteps  | 995014   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 236253   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17356    |
# |    fps              | 422      |
# |    time_elapsed     | 2354     |
# |    total timesteps  | 995103   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 236275   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17360    |
# |    fps              | 422      |
# |    time_elapsed     | 2355     |
# |    total timesteps  | 995292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 236322   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17364    |
# |    fps              | 422      |
# |    time_elapsed     | 2355     |
# |    total timesteps  | 995541   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 236385   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17368    |
# |    fps              | 422      |
# |    time_elapsed     | 2356     |
# |    total timesteps  | 995745   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 236436   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17372    |
# |    fps              | 422      |
# |    time_elapsed     | 2357     |
# |    total timesteps  | 996209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.76     |
# |    n_updates        | 236552   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17376    |
# |    fps              | 422      |
# |    time_elapsed     | 2358     |
# |    total timesteps  | 996425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 236606   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17380    |
# |    fps              | 422      |
# |    time_elapsed     | 2359     |
# |    total timesteps  | 996750   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75     |
# |    n_updates        | 236687   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17384    |
# |    fps              | 422      |
# |    time_elapsed     | 2359     |
# |    total timesteps  | 997093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00674  |
# |    n_updates        | 236773   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17388    |
# |    fps              | 422      |
# |    time_elapsed     | 2361     |
# |    total timesteps  | 997662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.55     |
# |    n_updates        | 236915   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17392    |
# |    fps              | 422      |
# |    time_elapsed     | 2361     |
# |    total timesteps  | 997882   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.73     |
# |    n_updates        | 236970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17396    |
# |    fps              | 422      |
# |    time_elapsed     | 2362     |
# |    total timesteps  | 997963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0138   |
# |    n_updates        | 236990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17400    |
# |    fps              | 422      |
# |    time_elapsed     | 2363     |
# |    total timesteps  | 998434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 237108   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17404    |
# |    fps              | 422      |
# |    time_elapsed     | 2364     |
# |    total timesteps  | 998840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00563  |
# |    n_updates        | 237209   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17408    |
# |    fps              | 422      |
# |    time_elapsed     | 2365     |
# |    total timesteps  | 999137   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0511   |
# |    n_updates        | 237284   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17412    |
# |    fps              | 422      |
# |    time_elapsed     | 2365     |
# |    total timesteps  | 999437   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 237359   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.1      |
# | time/               |          |
# |    episodes         | 17416    |
# |    fps              | 422      |
# |    time_elapsed     | 2366     |
# |    total timesteps  | 999573   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00949  |
# |    n_updates        | 237393   |
# ----------------------------------
# 100%|██████████████████████████████████████████████████████████████████████████████| 10/10 [6:21:22<00:00, 2288.25s/it]

# %%
for i in tqdm(range(n_simulations)):
    mean_reward, _ = ev.evaluate_random(gym.make('ctfsql-v0'), num_steps=10**5)
    print('random Mean reward: {0}'.format(mean_reward))
    mean_reward, _ = ev.evaluate_model(dqn_models[i], env, num_steps=10**5)
    print('dqn Mean reward: {0}'.format(mean_reward))
# Out:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# random Mean reward: -38.683
#  10%|████████▏                                                                         | 1/10 [01:46<15:57, 106.42s/it]
# dqn Mean reward: -102.391
# random Mean reward: -38.658
#  20%|████████████████▍                                                                 | 2/10 [03:32<14:08, 106.12s/it]
# dqn Mean reward: 5.88
# random Mean reward: -40.552
#  30%|████████████████████████▌                                                         | 3/10 [05:17<12:20, 105.78s/it]
# dqn Mean reward: -16.897
# random Mean reward: -39.232
#  40%|████████████████████████████████▊                                                 | 4/10 [07:03<10:34, 105.75s/it]
# dqn Mean reward: -1.709
# random Mean reward: -40.9
#  50%|█████████████████████████████████████████                                         | 5/10 [08:49<08:48, 105.75s/it]
# dqn Mean reward: 5.464
# random Mean reward: -40.235
#  60%|█████████████████████████████████████████████████▏                                | 6/10 [10:34<07:02, 105.69s/it]
# dqn Mean reward: 5.241
# random Mean reward: -40.579
#  70%|█████████████████████████████████████████████████████████▍                        | 7/10 [12:20<05:17, 105.72s/it]
# dqn Mean reward: -5.86
# random Mean reward: -39.257
#  80%|█████████████████████████████████████████████████████████████████▌                | 8/10 [14:15<03:37, 108.76s/it]
# dqn Mean reward: 5.585
# random Mean reward: -39.948
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 9/10 [16:10<01:50, 110.67s/it]
# dqn Mean reward: -90.741
# random Mean reward: -39.613
# 100%|█████████████████████████████████████████████████████████████████████████████████| 10/10 [18:05<00:00, 108.56s/it]
# dqn Mean reward: -120.248

# %%
#The array of positive 1, and negative total scores 0 are: [0,1,0,0,1,1,1,1,0,1]
x = [0,1,0,0,1,1,1,1,0,1]
len(x), sum(x)
# Out:
# (10, 6)

# %%
import evaluate14 as ev2
for i in tqdm(range(n_simulations)):
    mean_reward, _, median_reward = ev2.evaluate_model_deterministic(dqn_models[i], env, num_steps=10**5)
    print('dqn Mean reward: {0} median reward {1}'.format(mean_reward, median_reward))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-cca648f8296d> in <module>
# ----> 1 import evaluate14 as ev2
#       2 for i in tqdm(range(n_simulations)):
#       3     mean_reward, _, median_reward = ev2.evaluate_model_deterministic(dqn_models[i], env, num_steps=10**5)
#       4     print('dqn Mean reward: {0} median reward {1}'.format(mean_reward, median_reward))
#
# ModuleNotFoundError: No module named 'evaluate14'

# %%
import evaluate15 as ev2
for i in tqdm(range(n_simulations)):
    mean_reward, _, median_reward = ev2.evaluate_model_nondeter(dqn_models[i], env, num_steps=10**5)
    print('dqn Mean reward: {0} median reward {1}'.format(mean_reward, median_reward))
